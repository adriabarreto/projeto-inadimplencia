# %% [markdown]
# ### Etapa: Análise Exploratporia dos dados

# %% [markdown]
# O objetivo desta etapa do projeto é entender o dataset: Como está organizado e estruturado, quais as colunas, ou seja, de quais tipos de informações acerca dos clientes diposmos?
#
# Para tanto, vou usar ferramentas de visualização e calcular algumas estatísticas iniciais.

# %%
# Importando as bibliotecas necessárias à análise.

import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# Configuração dos gráficos
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
#Carregar arquivo .csv
#Esse dataset foi retirado do site Kaggle
df = pd.read_csv('C:/Users/adria/Documents/projeto-inadimplencia/data/UCI_Credit_Card.csv')

# %%
#Visualizar as primeiras linhas e colunas do dataset
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %% [markdown]
# ### Alguns problemas iniciais encontrados:
#
# - dados sobre gênero dos clientes são do tipo 'int', 2 e 1. Qual número representa o gênero masculino e qual representa o gênero feminino? Isso é relevante para a análise?
